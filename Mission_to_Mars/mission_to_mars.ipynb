# %%
# # ! pip install 'splinter[selenium4]'
# ! pip install splinter
# ! pip install webdriver_manager
# Out:
# ERROR: Invalid requirement: "'splinter[selenium4]'"
# Requirement already satisfied: splinter in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (0.18.1)
# Requirement already satisfied: webdriver_manager in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (3.8.5)
# Requirement already satisfied: packaging in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from webdriver_manager) (21.3)
# Requirement already satisfied: tqdm in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from webdriver_manager) (4.64.1)
# Requirement already satisfied: requests in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from webdriver_manager) (2.27.1)
# Requirement already satisfied: python-dotenv in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from packaging->webdriver_manager) (2.4.7)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from tqdm->webdriver_manager) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from requests->webdriver_manager) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from requests->webdriver_manager) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from requests->webdriver_manager) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\karina alvarez\anaconda3\envs\pythondata\lib\site-packages (from requests->webdriver_manager) (1.26.9)

# %%
import pandas as pd
import requests
import time

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://mars.nasa.gov/"

# %%
browser.visit(url)

# %%
response = requests.get(url)

# %%
soup = bs(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!-- Responsiveness -->
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!-- Favicon -->
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link color="#e48b55" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#000000" name="theme-color"/>
#   <meta content="authenticity_token" name="csrf-param">
#    <meta content="P4XZZh25JqpZnscEnCr1Yg469e/XHNmAmAcxUJ7YG7CnmarjjBUQPdISLyqpeTIu1TGzDyrk4U4E0qfkHb+l8A==" name="csrf-token">
#     <title>
#      NASA Mars Exploration
#     </title>
#     <meta content="NASA Mars Exploration" property="og:site_name"/>
#     <meta content="mars.nasa.gov" name="author"/>
#     <meta content="Mars, missions, NASA, rover, Curiosity, Opportunity, InSight, Mars Reconnaissance Orbiter, facts" name="keywords"/>
#     <meta content="NASA’s real-time portal for Mars exploration, featuring the latest news, images, and discoveries from the Red Planet." name="description"/>
#     <meta content="NASA’s real-time portal for Mars exploration, featuring the latest news, images, and discoveries from the Red Planet." property="og:description"/>
#     <meta content="NASA Mars Exploration" property="og:title"/>
#     <meta content="https://mars.nasa.gov/" property="og:url"/>
#     <meta content="2014-06-03 00:12:34 UTC" property="og:updated_time"/>
#     <meta content="https://mars.nasa.gov/system/site_config_values/meta_share_images/1_mars-nasa-gov.jpg" property="og:image"/>
#     <meta content="https://mars.nasa.gov/system/site_config_values/meta_share_images/1_mars-nasa-gov.jpg" name="twitter:image"/>
#     <link href="https://mars.nasa.gov/system/site_config_values/meta_share_images/1_mars-nasa-gov.jpg" rel="image_src"/>
#     <meta content="195570401081308" property="fb:app_id"/>
#     <link href="https://fonts.googleapis.com/css?family=Montserrat:200,300,400,500,600,700|Raleway:300,400" rel="stylesheet"/>
#     <link href="/assets/public_manifest-2d48ffe8e11602bb581d8fb94364038640b1a82ca086bb3cbd9023f5d4b06962.css" media="all" rel="stylesheet">
#      <link href="/assets/mbcms/vendor/jquery.fancybox3-d5d81bdfc05a59e4ea72bca1d8b7fcc399bd3b61f7c06af95a8a48795df69d7a.css" media="screen" rel="stylesheet">
#       <link href="/assets/gulp/print-240f8bfaa7f6402dfd6c49ee3c1ffea57a89ddd4c8c90e2f2a5c7d63c5753e32.css" media="print" rel="stylesheet">
#        <script src="/assets/public_manifest-cb74152d40cd7748c7401a121d06ab729336bddd12c4924bbd4efe9a9b50266c.js">
#        </script>
#        <script src="/assets/mbcms/vendor/jquery.fancybox3-bd543a29719f5c70e897670b5484b67824cc3c8eba68c8e4719d3cd6e2a5f542.js">
#        </script>
#        <script src="/assets/mb_manifest-0ef3196cc57659d51232d3fe4d5516f34d708b46802e673028d75aeadca20130.js">
#        </script>
#        <!--[if gt IE 8]><!-->
#        <script src="/assets/not_ie8_manifest.js">
#        </script>
#        <!--[if !IE]>-->
#        <script src="/assets/not_ie8_manifest.js">
#        </script>
#        <!--<![endif]-->
#        <script async="async" src="//script.crazyegg.com/pages/scripts/0070/1109.js" type="text/javascript">
#        </script>
#        <!-- /twitter cards -->
#        <meta content="summary_large_image" name="twitter:card"/>
#        <meta content="NASA Mars Exploration" name="twitter:title"/>
#        <meta content="NASA’s real-time portal for Mars exploration, featuring the latest news, images, and discoveries from the Red Planet." name="twitter:description"/>
#        <meta content="https://mars.nasa.gov/system/site_config_values/meta_share_images/1_mars-nasa-gov.jpg" name="twitter:image"/>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body id="home">
#   <svg display="none" height="0" width="0">
#    <symbol height="30" id="circle_plus" viewbox="0 0 30 30" width="30">
#     <g fill-rule="evenodd" transform="translate(1 1)">
#      <circle cx="14" cy="14" fill="#fff" fill-opacity=".1" fill-rule="nonzero" r="14" stroke="inherit" stroke-width="1">
#      </circle>
#      <path class="the_plus" d="m18.856 12.96v1.738h-4.004v3.938h-1.848v-3.938h-4.004v-1.738h4.004v-3.96h1.848v3.96z" fill="inherit" stroke-width="0">
#      </path>
#     </g>
#    </symbol>
#    <symbol height="30" id="circle_arrow" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
#     <g transform="translate(1 1)">
#      <circle cx="14" cy="14" fill="#fff" fill-opacity=".1" r="14" stroke="inherit" stroke-width="1">
#      </circle>
#      <path class="the_arrow" d="m8.5 15.00025h7.984l-2.342 2.42c-.189.197-.189.518 0 .715l.684.717c.188.197.494.197.684 0l4.35-4.506c.188-.199.188-.52 0-.717l-4.322-4.48c-.189-.199-.496-.199-.684 0l-.684.716c-.189.197-.189.519 0 .716l2.341 2.419h-8.011c-.276 0-.5.223-.5.5v1c0 .275.224.5.5.5z" fill="inherit" stroke-width="0">
#      </path>
#     </g>
#    </symbol>
#    <symbol height="30" id="circle_close" viewbox="0 0 30 30" width="30">
#     <g fill-rule="evenodd" transform="translate(1 1)">
#      <circle cx="14" cy="14" fill="blue" fill-opacity="1" fill-rule="nonzero" r="14" stroke="inherit" stroke-width="1">
#      </circle>
#      <path class="the_plus" d="m18.856 12.96v1.738h-4.004v3.938h-1.848v-3.938h-4.004v-1.738h4.004v-3.96h1.848v3.96z" fill="inherit" stroke-width="0">
#      </path>
#     </g>
#    </symbol>
#    <symbol height="30" id="circle_close_hover" viewbox="0 0 30 30" width="30">
#     <g fill-rule="evenodd" transform="translate(1 1)">
#      <circle cx="14" cy="14" fill="white" fill-opacity="1" fill-rule="nonzero" r="14" stroke="inherit" stroke-width="1">
#      </circle>
#      <path class="the_plus" d="m18.856 12.96v1.738h-4.004v3.938h-1.848v-3.938h-4.004v-1.738h4.004v-3.96h1.848v3.96z" fill="inherit" stroke-width="0">
#      </path>
#     </g>
#    </symbol>
#    <symbol height="6" id="chevron_down" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
#     <path d="m59 7v2.72727273l5 3.27272727 5-3.27272727v-2.72727273l-5 3.2727273z" transform="translate(-59 -7)">
#     </path>
#    </symbol>
#    <symbol height="16" id="gear" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#     <path d="m68 9h-1.09c-.15-.91-.5-1.75-1.021-2.471l.761-.77c.39-.39.39-1.029 0-1.42-.391-.39-1.021-.39-1.41 0l-.771.77c-.719-.519-1.469-.869-2.469-1.019v-1.09c0-.55-.45-1-1-1s-1 .45-1 1v1.09c-1 .15-1.75.5-2.47 1.02l-.77-.77c-.389-.39-1.029-.39-1.42 0-.39.391-.39 1.03 0 1.42l.771.77c-.521.72-.871 1.56-1.021 2.47h-1.09c-.55 0-1 .48-1 1.029 0 .551.45.971 1.12.971h.97c.15.91.5 1.75 1.021 2.471l-.771.769c-.39.39-.39 1.029 0 1.42.391.39 1.021.39 1.41 0l.78-.77c.72.52 1.47.87 2.47 1.02v1.09c0 .55.45 1 1 1s1-.45 1-1v-1.09c1-.15 1.75-.5 2.47-1.02l.771.77c.391.39 1.02.39 1.41 0 .39-.391.39-1.03 0-1.42l-.761-.76c.51-.72.87-1.56 1.02-2.48h1.09c.55 0 1-.45 1-1s-.45-1-1-1zm-7 4c-1.66 0-3-1.35-3-3s1.34-3 3-3c1.65 0 3 1.35 3 3s-1.35 3-3 3z" fill="#a79693" transform="translate(-53 -2)">
#     </path>
#    </symbol>
#   </svg>
#   <div data-react-cache-id="BrowseHappier-0" data-react-class="BrowseHappier" data-react-props='{"gt":1,"lt":11}'>
#   </div>
#   <div data-react-cache-id="HiPO-0" data-react-class="HiPO" data-react-props="{}">
#   </div>
#   <div id="main_container">
#    <div id="site_body">
#     <div class="site_header_area">
#      <header class="site_header">
#       <div class="brand_area">
#        <div class="brand1">
#         <a class="nasa_logo" href="http://www.nasa.gov" target="_blank" title="visit nasa.gov">
#          NASA
#         </a>
#        </div>
#        <div class="brand2">
#         <a class="top_logo" href="https://science.nasa.gov/" target="_blank" title="Explore NASA Science">
#          NASA Science
#         </a>
#         <a class="sub_logo" href="/mars-exploration/#" title="Mars">
#          Mars Exploration Program
#         </a>
#        </div>
#        <img alt="" class="print_only print_logo" src="/assets/logo_mars_trio_black@2x.png"/>
#       </div>
#       <a class="visuallyhidden focusable" href="#page">
#        Skip Navigation
#       </a>
#       <div class="right_header_container">
#        <a class="menu_button" href="javascript:void(0);" id="menu_button">
#         <span class="menu_icon">
#          menu
#         </span>
#        </a>
#        <a class="modal_close" id="modal_close">
#         <span class="modal_close_icon">
#         </span>
#        </a>
#        <div class="nav_area">
#         <div id="site_nav_container">
#          <nav class="site_nav" data-react-cache-id="Meganav-0" data-react-class="Meganav" data-react-props="{&quot;nav_items&quot;:[{&quot;name&quot;:&quot;Mars Now&quot;,&quot;style&quot;:&quot;icon&quot;,&quot;li_class&quot;:&quot;nav_icon mars_now&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;link&quot;:&quot;/explore/mars-now&quot;,&quot;svg_icon_id&quot;:&quot;nav_icon&quot;,&quot;id&quot;:261,&quot;features&quot;:[{&quot;title&quot;:&quot;Mars Now&quot;,&quot;body&quot;:&quot;View a 3D visualization of all the missions exploring the Red Planet&quot;,&quot;image_src&quot;:&quot;/system/basic_html_elements/225_mars_now_nav.jpg&quot;,&quot;link&quot;:&quot;/explore/mars-now/&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;categories&quot;:[]}],&quot;title&quot;:&quot;&quot;,&quot;short_description&quot;:&quot;View the current location and spacecraft communications activity of operating landers, rovers and orbiters using the NASA’s Mars Relay Network.&quot;},{&quot;name&quot;:&quot;The Red Planet&quot;,&quot;link&quot;:&quot;/#red_planet&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;sections&quot;:[{&quot;items&quot;:[{&quot;name&quot;:&quot;Dashboard&quot;,&quot;link&quot;:&quot;/#red_planet/0&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:9},{&quot;name&quot;:&quot;Science Goals&quot;,&quot;link&quot;:&quot;/#red_planet/1&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:13},{&quot;name&quot;:&quot;The Planet&quot;,&quot;link&quot;:&quot;/#red_planet/2&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:14},{&quot;name&quot;:&quot;Atmosphere&quot;,&quot;link&quot;:&quot;/#red_planet/3&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:16},{&quot;name&quot;:&quot;Astrobiology&quot;,&quot;link&quot;:&quot;/#red_planet/4&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:17},{&quot;name&quot;:&quot;Past, Present, Future, Timeline&quot;,&quot;link&quot;:&quot;/#red_planet/5&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:18}]}],&quot;id&quot;:3,&quot;meganav_style&quot;:&quot;&quot;,&quot;features&quot;:[],&quot;short_description&quot;:null},{&quot;name&quot;:&quot;The Program&quot;,&quot;link&quot;:&quot;/#mars_exploration_program&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;sections&quot;:[{&quot;items&quot;:[{&quot;name&quot;:&quot;Mission Statement&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/0&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:8},{&quot;name&quot;:&quot;About the Program&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/1&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:42},{&quot;name&quot;:&quot;Organization&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/2&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:43},{&quot;name&quot;:&quot;Why Mars?&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/3&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:51},{&quot;name&quot;:&quot;Research Programs&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/4&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:44},{&quot;name&quot;:&quot;Planetary Resources&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/5&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:52},{&quot;name&quot;:&quot;Technologies&quot;,&quot;link&quot;:&quot;/#mars_exploration_program/6&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:56}]}],&quot;id&quot;:2,&quot;meganav_style&quot;:&quot;&quot;,&quot;features&quot;:[],&quot;short_description&quot;:null},{&quot;name&quot;:&quot;News \u0026 Events&quot;,&quot;link&quot;:&quot;/#news_and_events&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;sections&quot;:[{&quot;items&quot;:[{&quot;name&quot;:&quot;News&quot;,&quot;link&quot;:&quot;/news&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:92},{&quot;name&quot;:&quot;Events&quot;,&quot;link&quot;:&quot;/events&quot;,&quot;target&quot;:&quot;_self&quot;,&quot;id&quot;:93}]}],&quot;id&quot;:4,&q ...
#          </nav>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <div id="sticky_nav_spacer">
#     </div>
#     <div id="page">
#      <div class="page_cover">
#      </div>
#      <script>
#       $(document).ready(function(){
#     //moved these here so they don't run on inner pages - RK
#     main.initSammy();
#     // main.setSols();
#     // main.setInsightLaunch();
#   })
#      </script>
#      <div class="homepage_dashboard_modal vital_signs_container" id="vital_signs_modal">
#      </div>
#      <!-- MAIN Carousel / Media Feature -->
#      <section id="homepage_feature_area">
#       <link href="/assets/vendor/masterslider/style/masterslider-a9540197c3d217858e40023d5f788714341a5d09000b077689987b25eca69c5d.css" media="screen" rel="stylesheet">
#        <link href="/assets/vendor/masterslider/style/default/style-151f21ae0588dd208aa4e128fbca4ee975ac7f869d86084b4dc413175d851dc6.css" media="screen" rel="stylesheet">
#         <script src="/assets/public/homepage_carousel_custom_fns-0f085eed551b7ccb9d54c363054d5bcb4becd19d74294f80dd1ce39976d955d5.js">
#         </script>
#         <section class="clearfix homepage_carousel main_feature">
#          <div class="master-slider ms-skin-default" data-bottom-margin="0" id="masterslider">
#           <article class="dark_background ms-slide slide-1" data-delay="8" data-fill-mode="fill">
#            <div class="gradient_container_top">
#            </div>
#            <img alt="slide 1 - NASA Selects New 'You've Got Perseverance' Awardees" data-src="/system/feature_items/images/6616_Youve_Got_Perseverance_MainArt_ELEVATED_FOR_ROTATOR.jpg" src="/system/feature_items/images/6616_Youve_Got_Perseverance_MainArt_ELEVATED_FOR_ROTATOR.jpg"/>
#            <div class="box floating_text_area left ms-layer" data-duration="300" data-ease="easeOutQuart" data-effect="right(90)" data-resize="false" data-type="text">
#             <h1 class="media_feature_title">
#              <a href="https://mars.nasa.gov/mars2020/participate/got-perseverance/awardees/#Opportunity-4" target="_self">
#               NASA Selects New 'You've Got Perseverance' Awardees
#              </a>
#              <span class="arrow">
#              </span>
#             </h1>
#             <div class="description">
#              20 students who have overcome academic challenges are being honored with a personal message from the Perseverance rover and a Dec. 6 virtual meetup with team members.
#              <footer>
#               <a class="multi_links" href="https://mars.nasa.gov/mars2020/participate/got-perseverance/awardees/#Opportunity-4" target="_self">
#                Awardee List
#               </a>
#               <a class="multi_links" href="https://mars.nasa.gov/mars2020/participate/got-perseverance/nominate/" target="_self">
#                Nominate a Student
#               </a>
#              </footer>
#             </div>
#            </div>
#            <div class="gradient_container_bottom">
#            </div>
#           </article>
#           <article class="dark_background ms-slide slide-2" data-delay="8" data-fill-mode="fill">
#            <div class="gradient_container_top">
#            </div>
#            <img alt="slide 2 - Video still from the Mars Sample Return trailer." data-src="/system/feature_items/images/6614_MSRAnimationTrailer-ROTATOR2.jpg" src="/system/feature_items/images/6614_MSRAnimationTrailer-ROTATOR2.jpg"/>
#            <div class="box floating_text_area ms-layer right" data-duration="300" data-ease="easeOutQuart" data-effect="right(90)" data-resize="false" data-type="text">
#             <h2 class="category_title">
#              VIDEO
#             </h2>
#             <h1 class="media_feature_title">
#              <a href="https://mars.nasa.gov/msr/multimedia/videos/?v=523" target="_self">
#               How Mars Samples Would Return To Earth
#              </a>
#              <span class="arrow">
#              </span>
#             </h1>
#             <div class="description">
#              Get a sneak peak of the intricate acrobatics planned for the spacecraft in the Mars Sample Return Campaign. The bold plan calls for an extraction team to safely bring to Earth Mars samples collected by NASA’s Perseverance rover.
#              <footer>
#               <a class="button" href="https://mars.nasa.gov/msr/multimedia/videos/?v=523" target="_self">
#                Watch Video
#               </a>
#              </footer>
#             </div>
#            </div>
#            <div class="gradient_container_bottom">
#            </div>
#           </article>
#           <article class="dark_background ms-slide slide-3" data-delay="8" data-fill-mode="fill">
#            <div class="gradient_container_top">
#            </div>
#            <img alt="slide 3 - Mars Helicopter Sol 625 - Navigation Camera: NASA's Ingenuity Mars Helicopter acquired this image using its navigation camera." data-src="/system/feature_items/images/6617_HNM_0625_0722439897_115ECM_N0340001HELI00959_0000A0J01_1200.jpeg" src="/system/feature_items/images/6617_HNM_0625_0722439897_115ECM_N0340001HELI00959_0000A0J01_1200.jpeg"/>
#            <div class="box floating_text_area ms-layer right" data-duration="300" data-ease="easeOutQuart" data-effect="right(90)" data-resize="false" data-type="text">
#             <h2 class="category_title">
#              HELICOPTER BLOG
#             </h2>
#             <h1 class="media_feature_title">
#              <a href="https://mars.nasa.gov/technology/helicopter/status/420/" target="_self">
#               Flight 34 Was Short But Significant
#              </a>
#             </h1>
#             <div class="description">
#              <footer>
#               <a class="button" href="https://mars.nasa.gov/technology/helicopter/status/420/" target="_self">
#                READ MORE
#               </a>
#              </footer>
#             </div>
#            </div>
#            <div class="gradient_container_bottom">
#            </div>
#           </article>
#           <article class="dark_background ms-slide slide-4" data-delay="8" data-fill-mode="fill">
#            <div class="gradient_container_top">
#            </div>
#            <img alt="slide 4 - Mars Perseverance Sol 615 - Right Mastcam-Z Camera: NASA's Mars Perseverance rover acquired this image using its Right Mastcam-Z camera. Mastcam-Z is a pair of cameras located high on the rover's mast." data-src="/system/feature_items/images/6618_ZR0_0615_0721540472_488EBY_N0301172ZCAM08622_0340LMJ01_1200.jpeg" src="/system/feature_items/images/6618_ZR0_0615_0721540472_488EBY_N0301172ZCAM08622_0340LMJ01_1200.jpeg"/>
#            <div class="box floating_text_area ms-layer right" data-duration="300" data-ease="easeOutQuart" data-effect="right(90)" data-resize="false" data-type="text">
#             <h2 class="category_title">
#              ROVER BLOG
#             </h2>
#             <h1 class="media_feature_title">
#              <a href="https://mars.nasa.gov/mars2020/mission/status/419/a-picture-is-worth-a-thousand-words/" target="_self">
#               A Picture Is Worth a Thousand Words
#              </a>
#             </h1>
#             <div class="description">
#              <footer>
#               <a class="button" href="https://mars.nasa.gov/mars2020/mission/status/419/a-picture-is-worth-a-thousand-words/" target="_self">
#                READ MORE
#               </a>
#              </footer>
#             </div>
#            </div>
#            <div class="gradient_container_bottom">
#            </div>
#           </article>
#           <article class="dark_background ms-slide slide-5" data-delay="8" data-fill-mode="fill">
#            <div class="gradient_container_top">
#            </div>
#            <img alt="slide 5 - The Power of the Rovers" data-src="/system/feature_items/images/6613_PIA14175-ROTATOR.jpg" src="/system/feature_items/images/6613_PIA14175-ROTATOR.jpg"/>
#            <div class="box floating_text_area ms-layer right" data-duration="300" data-ease="easeOutQuart" data-effect="right(90)" data-resize="false" data-type="text">
#             <h2 class="category_title">
#              PODCAST EPISODE
#             </h2>
#             <h1 class="media_feature_title">
#              <a href="/resources/27127" target="_self">
#               The Power of the Rovers
#              </a>
#              <span class="arrow">
#              </span>
#             </h1>
#             <div class="description">
#              The latest episode explores how a Mars rover keeps driving on a planet with no gas stations.
#              <footer>
#               <a class="button" href="/resources/27127" target="_self">
#                LISTEN NOW
#               </a>
#              </footer>
#             </div>
#            </div>
#            <div class="gradient_container_bottom">
#            </div>
#           </article>
#           <article class="dark_background ms-slide slide-6" data-delay="8" data-fill-mode="fill">
#            <div class="gradient_container_top">
#            </div>
#            <img alt="slide 6 - boarding pass to Mars" data-src="/system/feature_items/images/5985_mars2020-sendname-home2.jpg" src="/system/feature_items/images/5985_mars2020-sendname-home2.jpg"/>
#            <div class="box floating_text_area ms-layer right" data-duration="300" data-ease="easeOutQuart" data-effect="right(90)" data-resize="false" data-type="text">
#             <h1 class="media_feature_title">
#              <a href="https://mars.nasa.gov/participate/send-your-name/future" target="_self">
#               Join 20 Million People and Send Your Name to Mars
#              </a>
#              <span class="arrow">
#              </span>
#             </h1>
#             <div class="description">
#              Sign up to send your name on our next mission to Mars.
#              <footer>
#               <a class="button" href="https://mars.nasa.gov/participate/send-your-name/future" target="_self">
#                SIGN UP
#               </a>
#              </footer>
#             </div>
#            </div>
#            <div class="gradient_container_bottom">
#            </div>
#           </article>
#          </div>
#         </section>
#         <!-- Or, if there is only one article use a conditional inside this partial -->
#        </link>
#       </link>
#      </section>
#      <section class="vital_signs_menu homepage_dashboard_container">
#       <div class="page_dashboard" data-react-cache-id="PageDashboard-0" data-react-class="PageDashboard" data-react-props="{&quot;options&quot;:[{&quot;type&quot;:&quot;sols_on_mars&quot;,&quot;sol_0&quot;:49268,&quot;deg_east&quot;:137.406,&quot;title&quot;:&quot;Curiosity&quot;,&quot;mep_overlay&quot;:&quot;/mars-exploration/overlay-curiosity/&quot;},{&quot;type&quot;:&quot;sols_on_mars&quot;,&quot;sol_0&quot;:52303,&quot;deg_east&quot;:77.4326,&quot;title&quot;:&quot;Perseverance&quot;,&quot;mep_overlay&quot;:&quot;/mars-exploration/overlay-mars2020/&quot;},{&quot;type&quot;:&quot;sols_on_mars&quot;,&quot;sol_0&quot;:51510,&quot;deg_east&quot;:135.827,&quot;title&quot;:&quot;InSight&quot;,&quot;mep_overlay&quot;:&quot;/mars-exploration/overlay-insight/&quot;},{&quot;title&quot;:&quot;Orbiters&quot;,&quot;value&quot;:&quot;3 Missions at Mars&quot;,&quot;mep_overlay&quot;:&quot;/mars-exploration/overlay-odyssey/&quot;},{&quot;title&quot;:&quot;Future&quot;,&quot;value&quot;:&quot;What's Next&quot;,&quot;mep_overlay&quot;:&quot;/mars-exploration/overlay-humans/&quot;}],&quot;single_slide&quot;:false}">
#       </div>
#      </section>
#      <!-- / commenting out Intro screen per request from client - OS -->
#      <!-- /= javascript_include_tag "public/intro_screen" -->
#      <script src="/assets/public/vital_signs-451aaacda0e6ffcecdb1dacce8d72a08ff9e57aaf0d817f1aab415f5c1a88018.js">
#      </script>
#      <section class="more_bar">
#       <div class="title">
#        MORE
#       </div>
#       <div class="arrow_down">
#       </div>
#      </section>
#      <!-- / adding for Mars 2020 launch -->
#      <input id="insight_arrival_date" name="insight_arrival_date" type="hidden" value="2018-11-26T19:54:00Z"/>
#      <!-- 'definition_teaser' -->
#      <section class="parallax_categorized_teaser" id="red_planet_section">
#       <div class="module_content">
#        <div class="nav_content_container">
#         <header class="mobile_only">
#          <div class="module_title">
#           The Red Planet
#          </div>
#         </header>
#         <nav class="catcont_nav desktop_catcont_nav">
#          <header>
#           <div class="module_title">
#            The Red Planet
#           </div>
#          </header>
#          <ul>
#           <li class="current default section" data-idx="0">
#            <!-- .nav_title -->
#            <!-- = section.title -->
#            <div class="category_info">
#             <div class="title">
#              Dashboard
#             </div>
#            </div>
#           </li>
#           <li class="section" data-idx="1">
#            <!-- .nav_title -->
#            <!-- = section.title -->
#            <div class="category_info">
#             <div class="title">
#              Science Goals
#             </div>
#             <div class="description">
#              The Mars Exploration Program studies Mars as a planetary system in order to understand the formation and early evolution of Mars as a planet, the history of geological processes that have shaped Mars through time, the potential for Mars to have hosted life, and the future exploration of Mars by humans. The strategy has evolved as we have learned more about Mars and as more questions have arisen. We have gone from “Follow the Water” to “Explore Habitability” to “Seek Signs of Life.”
#             </div>
#            </div>
#           </li>
#           <li class="section" data-idx="2">
#            <!-- .nav_title -->
#            <!-- = section.title -->
#            <div class="category_info">
#             <div class="title">
#              The Planet
#             </div>
#            </div>
#           </li>
#           <li class="section" data-idx="3">
#            <!-- .nav_title -->
#            <!-- = section.title -->
#            <div class="category_info">
#             <div class="title">
#              Atmosphere
#             </div>
#            </div>
#           </li>
#           <li class="section" data-idx="4">
#            <!-- .nav_title -->
#            <!-- = section.title -->
#            <div class="category_info">
#             <div class="title">
#              Astrobiology
#             </div>
#            </div>
#           </li>
#           <li class="section" data-idx="5">
#            <!-- .nav_title -->
#            <!-- = section.title -->
#            <div class="category_info">
#             <div class="title">
#              Past, Present, Future, Timeline
#             </div>
#            </div>
#           </li>
#          </ul>
#         </nav>
#         <div class="categorized_content wysiwyg_content">
#          <nav class="catcont_nav current mobile_catcont_nav" data-idx="0">
#           <div class="section">
#            <div class="category_info">
#             <div class="title">
#              Dashboard
#             </div>
#            </div>
#           </div>
#          </nav>
#          <div class="bubble_container content_for current" data-idx="0">
#           <div class="bubble_container_contents">
#            <div class="data detail_carousel oculus" id="data_119">
#             <h3 class="carousel_title">
#              DATA
#             </h3>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 DATA:
#                </span>
#                TODAY'S WEATHER (°F)
#               </h3>
#               <div class="description">
#                <div class="weather">
#                 <div class="cols">
#                  <div class="col high">
#                   <div class="val">
#                    -4°
#                   </div>
#                   <div class="val_label">
#                    high
#                   </div>
#                  </div>
#                  <div class="col low">
#                   <div class="val">
#                    -98°
#                   </div>
#                   <div class="val_label">
#                    low
#                   </div>
#                  </div>
#                 </div>
#                 <div class="note">
#                  <div class="sol">
#                   Sol
# 3039
# – MSL
#                  </div>
#                  <!-- .earth_date -->
#                  <!-- Earth date #{report.terrestrial_date.strftime('%b %d, %Y')} -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 DATA:
#                </span>
#                TODAY'S WEATHER (°C)
#               </h3>
#               <div class="description">
#                <div class="weather">
#                 <div class="cols">
#                  <div class="col high">
#                   <div class="val">
#                    -20°
#                   </div>
#                   <div class="val_label">
#                    high
#                   </div>
#                  </div>
#                  <div class="col low">
#                   <div class="val">
#                    -72°
#                   </div>
#                   <div class="val_label">
#                    low
#                   </div>
#                  </div>
#                 </div>
#                 <div class="note">
#                  <div class="sol">
#                   Sol
# 3039
# – MSL
#                  </div>
#                  <!-- .earth_date -->
#                  <!-- Earth date #{report.terrestrial_date.strftime('%b %d, %Y')} -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 DATA:
#                </span>
#                SUNRISE, SUNSET
#               </h3>
#               <div class="description">
#                <div class="weather">
#                 <div class="cols">
#                  <div class="col sunrise">
#                   <div class="val">
#                    6:37
#                   </div>
#                   <div class="val_label">
#                    AM
#                   </div>
#                  </div>
#                  <div class="col sunset">
#                   <div class="val">
#                    6:35
#                   </div>
#                   <div class="val_label">
#                    PM
#                   </div>
#                  </div>
#                 </div>
#                 <div class="note">
#                  <div class="sol">
#                   Sol
# 3039
# – MSL
#                  </div>
#                  <!-- .earth_date -->
#                  <!-- Earth date #{report.terrestrial_date.strftime('%b %d, %Y')} -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 DATA:
#                </span>
#                ATMOSPHERE
#               </h3>
#               <div class="description">
#                <div class="weather">
#                 <div class="cols">
#                  <div class="col">
#                   <div class="val small_text">
#                    Moderate
#                   </div>
#                   <div class="val_label">
#                    UV
#                   </div>
#                  </div>
#                  <div class="col">
#                   <div class="val small_text">
#                    Sunny
#                   </div>
#                   <div class="val_label">
#                    Condition
#                   </div>
#                  </div>
#                 </div>
#                 <div class="note">
#                  <div class="sol">
#                   Sol
# 3039
# – MSL
#                  </div>
#                  <!-- .earth_date -->
#                  <!-- Earth date #{report.terrestrial_date.strftime('%b %d, %Y')} -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 DATA:
#                </span>
#                SEASON
#               </h3>
#               <div class="description">
#                <div class="weather">
#                 <div class="cols">
#                  <!-- .col -->
#                  <!-- .val -->
#                  <!-- = report.ls.to_s -->
#                  <!-- .val_label -->
#                  <!-- Ls -->
#                  <div class="col">
#                   <div class="val">
#                    Spring
#                   </div>
#                   <!-- .val_label -->
#                   <!-- season -->
#                  </div>
#                 </div>
#                 <div class="note">
#                  <div class="sol">
#                   Sol
# 3039
# – MSL
#                  </div>
#                  <!-- .earth_date -->
#                  <!-- Earth date #{report.terrestrial_date.strftime('%b %d, %Y')} -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 DATA:
#                </span>
#                PRESSURE
#               </h3>
#               <div class="description">
#                <div class="weather">
#                 <div class="cols">
#                  <div class="col">
#                   <div class="val">
#                    827
#                   </div>
#                   <div class="val_label">
#                    mean Pascals
#                   </div>
#                  </div>
#                  <!-- .col -->
#                  <!-- .val -->
#                  <!-- = report.pressure_string -->
#                 </div>
#                 <div class="note">
#                  <div class="sol">
#                   Sol
# 3039
# – MSL
#                  </div>
#                  <!-- .earth_date -->
#                  <!-- Earth date #{report.terrestrial_date.strftime('%b %d, %Y')} -->
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <script>
#             $("#data_119").slick()
#            </script>
#            <div class="detail_carousel images oculus" id="images_121">
#             <h3 class="carousel_title">
#              RECENT IMAGES
#             </h3>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/27056_PIA25419-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Perseverance Views Phobos
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/27056/perseverance-views-phobos/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Perseverance Views Phobos
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26978_PIA24921_MAIN-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Detailed Panorama of Mars' Jezero Crater Delta
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26978/detailed-panorama-of-mars-jezero-crater-delta/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Detailed Panorama of Mars' Jezero Crater Delta
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26895_PIA25326-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Mars Sample Return Concept Illustration
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26895/mars-sample-return-concept-illustration/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Mars Sample Return Concept Illustration
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26695_2-PIA25217-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Rover Landing Gear Seen From the Air by Mars Helicopter
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26695/rover-landing-gear-seen-from-the-air-by-mars-helicopter/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Rover Landing Gear Seen From the Air by Mars Helicopter
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26696_e-PIA25218-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Debris Field From Perseverance Landing Gear Seen by Mars Helicopter
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26696/debris-field-from-perseverance-landing-gear-seen-by-mars-helicopter/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Debris Field From Perseverance Landing Gear Seen by Mars Helicopter
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26671_PIA25178-320x240.gif"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                InSight Captures a Martian Sunrise and Sunset
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26671/insight-captures-a-martian-sunrise-and-sunset/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 InSight Captures a Martian Sunrise and Sunset
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26654_PIA25175-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Curiosity Finds 'Gator-Back' Rocks on 'Greenheugh'
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26654/curiosity-finds-gator-back-rocks-on-greenheugh/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Curiosity Finds 'Gator-Back' Rocks on 'Greenheugh'
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26587_PIA25077-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Curiosity Finds a Martian 'Flower'
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26587/curiosity-finds-a-martian-flower/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Curiosity Finds a Martian 'Flower'
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26526_PIA25046-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Curiosity Mastcam's View of 'Edinburgh'
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26526/curiosity-mastcams-view-of-edinburgh/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Curiosity Mastcam's View of 'Edinburgh'
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="slide">
#              <div class="image_container">
#               <img src="/system/resources/list_images/26384_PIA24938-320x240.jpg"/>
#              </div>
#              <div class="slide_description">
#               <h3 class="description_title">
#                Two Versions of a Curiosity Selfie: Narrow and Wide
#               </h3>
#              </div>
#              <a class="hover_state" href="/resources/26384/two-versions-of-a-curiosity-selfie-narrow-and-wide/" target="_self">
#               <div class="rollover_description">
#                <div class="title">
#                 Two Versions of a Curiosity Selfie: Narrow and Wide
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <script>
#             $("#images_121").slick()
#            </script>
#            <div class="compare detail_carousel oculus" id="compare_120">
#             <h3 class="carousel_title">
#              COMPARE
#             </h3>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 COMPARE:
#                </span>
#                DISTANCE FROM SUN
#               </h3>
#               <div class="description">
#                <div class="comparison">
#                 <div class="cols">
#                  <div class="col thing_one">
#                   <div class="thing">
#                    MARS
#                   </div>
#                   <div class="val">
#                    142
#                   </div>
#                  </div>
#                  <div class="col thing_two">
#                   <div class="thing">
#                    EARTH
#                   </div>
#                   <div class="val">
#                    93
#                   </div>
#                  </div>
#                 </div>
#                 <div class="details">
#                  millions of miles avg.
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 COMPARE:
#                </span>
#                DEEPEST CANYON
#               </h3>
#               <div class="description">
#                <div class="comparison">
#                 <div class="cols">
#                  <div class="col thing_one">
#                   <div class="thing">
#                    VALLES MARINERIS
#                   </div>
#                   <div class="val">
#                    4.35
#                   </div>
#                  </div>
#                  <div class="col thing_two">
#                   <div class="thing">
#                    GRAND CANYON
#                   </div>
#                   <div class="val">
#                    1.1
#                   </div>
#                  </div>
#                 </div>
#                 <div class="details">
#                  miles deep
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 COMPARE:
#                </span>
#                DIAMETER
#               </h3>
#               <div class="description">
#                <div class="comparison">
#                 <div class="cols">
#                  <div class="col thing_one">
#                   <div class="thing">
#                    MARS
#                   </div>
#                   <div class="val">
#                    4,220
#                   </div>
#                  </div>
#                  <div class="col thing_two">
#                   <div class="thing">
#                    EARTH
#                   </div>
#                   <div class="val">
#                    7,926
#                   </div>
#                  </div>
#                 </div>
#                 <div class="details">
#                  miles
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 COMPARE:
#                </span>
#                LENGTH OF DAY
#               </h3>
#               <div class="description">
#                <div class="comparison">
#                 <div class="cols">
#                  <div class="col thing_one">
#                   <div class="thing">
#                    MARS
#                   </div>
#                   <div class="val">
#                    24:37
#                   </div>
#                  </div>
#                  <div class="col thing_two">
#                   <div class="thing">
#                    EARTH
#                   </div>
#                   <div class="val">
#                    23:56
#                   </div>
#                  </div>
#                 </div>
#                 <div class="details">
#                  hours:minutes
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="slide">
#              <div class="slide_description">
#               <h3 class="description_title">
#                <span class="mobile_only_title">
#                 COMPARE:
#                </span>
#                HIGHEST MOUNTAIN
#               </h3>
#               <div class="description">
#                <div class="comparison">
#                 <div class="cols">
#                  <div class="col thing_one">
#                   <div class="thing">
#                    OLYMPUS MONS
#                   </div>
#                   <div class="val">
#                    16
#                   </div>
#                  </div>
#                  <div class="col thing_two">
#                   <div class="thing">
#                    MAUNA KEA
#                   </div>
#                   <div class="val">
#                    6.34
#                   </div>
#                  </div>
#                 </div>
#                 <div class="details">
#                  miles (approximate)
# ...
#            <div class="rollover_description">
#             Meet some of the faces behind the Mars Exploration Program.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="People" class="thumb" src="/system/feature_items/images/19_missionteam-400x225.jpg"/>
#           </div>
#           <a class="slide_title" href="https://mars.nasa.gov/people/" target="_self">
#            People
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="https://mars.nasa.gov/multimedia/resources/mars-posters-explorers-wanted/" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             Join us as we explore with robots and send humans there one day. Download a Mars poster that speaks to you.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Mars Explorers Wanted" class="thumb" src="/system/feature_items/images/6137_MarsExplorersWanted_600x338.jpg"/>
#           </div>
#           <a class="slide_title" href="https://mars.nasa.gov/multimedia/resources/mars-posters-explorers-wanted/" target="_self">
#            Mars Explorers Wanted
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="/all-about-mars/facts/" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             An overview of basics about the Red Planet.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Mars facts" class="thumb" src="/system/feature_items/images/16_Mars-Valles_Marineris600x338.jpg"/>
#           </div>
#           <a class="slide_title" href="/all-about-mars/facts/" target="_self">
#            Amazing Facts
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="https://trek.nasa.gov/mars/" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             Explore Martian terrain maps with this interactive visualization tool.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Mars Trek" class="thumb" src="/system/feature_items/images/17_LMMP_thumb.jpg"/>
#           </div>
#           <a class="slide_title" href="https://trek.nasa.gov/mars/" target="_self">
#            Mars Trek
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="/multimedia/videos/?category=199" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             Short, animated answers to common questions about Mars ... in just 60 seconds.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Mars in a minute" class="thumb" src="/system/feature_items/images/20_Mars_minute_thumb_600x338.jpg"/>
#           </div>
#           <a class="slide_title" href="/multimedia/videos/?category=199" target="_self">
#            Mars in a Minute
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="https://mars.nasa.gov/allaboutmars/mystique/" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             How the Red Planet has been envisioned in humankind's creative imagination.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Mars in pop culture" class="thumb" src="/system/feature_items/images/21_Screen_Shot_2017-03-16_at_1.09.26_PM.png"/>
#           </div>
#           <a class="slide_title" href="https://mars.nasa.gov/allaboutmars/mystique/" target="_self">
#            Pop Culture Mars
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="/all-about-mars/night-sky/opposition" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             How and where to spot the Red Planet overhead.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Mars in the Night Sky" class="thumb" src="/system/feature_items/images/5715_NightSky-thumb600x338.jpg"/>
#           </div>
#           <a class="slide_title" href="/all-about-mars/night-sky/opposition" target="_self">
#            Mars in the Night Sky
#           </a>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="https://mars.jpl.nasa.gov/ask-nasa-mars/" target="_self">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             Curious about Mars? Ask ROV-E.
#             <div class="overlay_arrow">
#              <img alt="More" src="/assets/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Ask a Question" class="thumb" src="/system/feature_items/images/5714_Ask_a_question_thumb_600x338.jpg"/>
#           </div>
#           <a class="slide_title" href="https://mars.jpl.nasa.gov/ask-nasa-mars/" target="_self">
#            Ask a Question
#           </a>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </section>
#     </div>
#     <footer id="site_footer">
#      <div class="grid_layout">
#       <section class="upper_footer">
#        <div class="share_newsletter_container">
#         <div class="newsletter">
#          <h2>
#           Get the Mars Newsletter
#          </h2>
#          <form action="/newsletter-subscribe">
#           <input id="email" name="email" placeholder="enter email address" type="email" value=""/>
#           <input data-disable-with="" name="commit" type="submit" value=""/>
#          </form>
#         </div>
#         <div class="share">
#          <h2>
#           Follow the Journey
#          </h2>
#          <div class="social_icons">
#           <!-- AddThis Button BEGIN -->
#           <div class="addthis_toolbox addthis_default_style addthis_32x32_style">
#            <a addthis:userid="MarsCuriosity" class="addthis_button_twitter_follow icon">
#             <img alt="twitter" src="/assets/twitter_icon@2x.png"/>
#            </a>
#            <a addthis:userid="MarsCuriosity" class="addthis_button_facebook_follow icon">
#             <img alt="facebook" src="/assets/facebook_icon@2x.png"/>
#            </a>
#            <a addthis:userid="nasa" class="addthis_button_instagram_follow icon">
#             <img alt="instagram" src="/assets/instagram_icon@2x.png"/>
#            </a>
#            <a addthis:url="https://mars.nasa.gov/rss/api/?feed=news&amp;category=all&amp;feedtype=rss" class="addthis_button_rss_follow icon">
#             <img alt="rss" src="/assets/rss_icon@2x.png"/>
#            </a>
#           </div>
#          </div>
#          <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5a690e4c1320e328">
#          </script>
#         </div>
#        </div>
#        <div class="gradient_line">
#        </div>
#       </section>
#       <section class="sitemap">
#        <div class="sitemap_directory" id="sitemap_directory">
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            <a href="/#red_planet">
#             The Red Planet
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <div class="global_subnav_container">
#              <ul class="subnav">
#               <li>
#                <a href="/#red_planet/0" target="_self">
#                 Dashboard
#                </a>
#               </li>
#               <li>
#                <a href="/#red_planet/1" target="_self">
#                 Science Goals
#                </a>
#               </li>
#               <li>
#                <a href="/#red_planet/2" target="_self">
#                 The Planet
#                </a>
#               </li>
#               <li>
#                <a href="/#red_planet/3" target="_self">
#                 Atmosphere
#                </a>
#               </li>
#               <li>
#                <a href="/#red_planet/4" target="_self">
#                 Astrobiology
#                </a>
#               </li>
#               <li>
#                <a href="/#red_planet/5" target="_self">
#                 Past, Present, Future, Timeline
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            <a href="/#mars_exploration_program">
#             The Program
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <div class="global_subnav_container">
#              <ul class="subnav">
#               <li>
#                <a href="/#mars_exploration_program/0" target="_self">
#                 Mission Statement
#                </a>
#               </li>
#               <li>
#                <a href="/#mars_exploration_program/1" target="_self">
#                 About the Program
#                </a>
#               </li>
#               <li>
#                <a href="/#mars_exploration_program/2" target="_self">
#                 Organization
#                </a>
#               </li>
#               <li>
#                <a href="/#mars_exploration_program/3" target="_self">
#                 Why Mars?
#                </a>
#               </li>
#               <li>
#                <a href="/#mars_exploration_program/4" target="_self">
#                 Research Programs
#                </a>
#               </li>
#               <li>
#                <a href="/#mars_exploration_program/5" target="_self">
#                 Planetary Resources
#                </a>
#               </li>
#               <li>
#                <a href="/#mars_exploration_program/6" target="_self">
#                 Technologies
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            <a href="/#news_and_events">
#             News &amp; Events
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <div class="global_subnav_container">
#              <ul class="subnav">
#               <li>
#                <a href="/news" target="_self">
#                 News
#                </a>
#               </li>
#               <li>
#                <a href="/events" target="_self">
#                 Events
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            <a href="/#multimedia">
#             Multimedia
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <div class="global_subnav_container">
#              <ul class="subnav">
#               <li>
#                <a href="/multimedia/images/" target="_self">
#                 Images
#                </a>
#               </li>
#               <li>
#                <a href="/multimedia/videos/" target="_self">
#                 Videos
#                </a>
#               </li>
#               <li>
#                <a href="/mars2020/multimedia/audio/" target="_self">
#                 Audio
#                </a>
#               </li>
#               <li>
#                <a href="/multimedia/podcasts/" target="_self">
#                 Podcasts
#                </a>
#               </li>
#               <li>
#                <a href="/multimedia/more-resources/" target="_self">
#                 More Resources
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            <a href="/#missions_gallery_subnav">
#             Missions
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <div class="global_subnav_container">
#              <ul class="subnav">
#               <li>
#                <a href="/mars-exploration/missions/?category=167" target="_self">
#                 Past
#                </a>
#               </li>
#               <li>
#                <a href="/mars-exploration/missions/?category=170" target="_self">
#                 Present
#                </a>
#               </li>
#               <li>
#                <a href="/mars-exploration/missions/?category=171" target="_self">
#                 Future
#                </a>
#               </li>
#               <li>
#                <a href="/mars-exploration/partners" target="_self">
#                 International Partners
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            <a href="/#more">
#             More
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <div class="global_subnav_container">
#              <ul class="subnav">
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="gradient_line">
#        </div>
#       </section>
#       <section class="lower_footer">
#        <div class="nav_container">
#         <nav>
#          <ul>
#           <li>
#            <a href="http://science.nasa.gov/" target="_blank">
#             NASA Science Mission Directorate
#            </a>
#           </li>
#           <li>
#            <a href="https://www.jpl.nasa.gov/copyrights.php" target="_blank">
#             Privacy
#            </a>
#           </li>
#           <li>
#            <a href="http://www.jpl.nasa.gov/imagepolicy/" target="_blank">
#             Image Policy
#            </a>
#           </li>
#           <li>
#            <a href="https://mars.nasa.gov/feedback/" target="_self">
#             Feedback
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#        <div class="credits">
#         <div class="footer_brands_top">
#          <p>
#           Managed by the Mars Exploration Program and the Jet Propulsion Laboratory for NASA’s Science Mission Directorate
#          </p>
#         </div>
#         <!-- .footer_brands -->
#         <!-- %a.jpl{href: "", target: "_blank"}Institution -->
#         <!-- -->
#         <!-- %a.caltech{href: "", target: "_blank"}Institution -->
#         <!-- .staff -->
#         <!-- %p -->
#         <!-- - get_staff_for_category(get_field_from_admin_config(:web_staff_category_id)) -->
#         <!-- - @staff.each_with_index do |staff, idx| -->
#         <!-- - unless staff.is_in_footer == 0 -->
#         <!-- = staff.title + ": " -->
#         <!-- - if staff.contact_link =~ /@/ -->
#         <!-- = mail_to staff.contact_link, staff.name, :subject => "[#{@site_title}]" -->
#         <!-- - elsif staff.contact_link.present? -->
#         <!-- = link_to staff.name, staff.contact_link -->
#         <!-- - else -->
#         <!-- = staff.name -->
#         <!-- - unless (idx + 1 == @staff.size) -->
#         <!-- %br -->
#        </div>
#       </section>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;subagency=JPL-Mars-MEPJPL&amp;pua=UA-9453474-9,UA-118212757-11&amp;dclink=true&amp;sp=searchbox&amp;exts=tif,tiff,wav" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
title = soup.find("h1", class_="media_feature_title").find("a").text

news_p = soup.find("div", class_="description").find("a").text

# %%
print(title)

print(news_p)
# Out:
# NASA Selects New 'You've Got Perseverance' Awardees
#
#
# Awardee List
